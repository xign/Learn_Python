# %%
from ggplot import *

# %%
print ggplot(mtcars, aes('mpg','qsec')) + geom_point(color = 'green') \
+ scale_x_continuous(breaks = [10,20,30], labels = ["horrible","ok","awesome"])
# Out:
# <ggplot: (285198561)>

# %%
print ggplot(meat, aes('date','beef * 2000')) + \
geom_line(color = "coral") + \
scale_x_date(breaks = date_breaks('36 months'), labels = '%Y') +\
scale_y_continuous(labels = 'millions')
# Out:
# <ggplot: (292348337)>

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
np.random.seed(sum(ord(x) for x in "aesthetics"))

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
import seaborn as sns
sinplot()

# %%
sns.set_style("darkgrid")
data = np.random.normal(size = (20,6)) + np.arange(6) / 2
sns.boxplot(data);

# %%
sns.set_style("dark")
sinplot()

# %%
sns.set_style("white")
sinplot()
sns.despine()

# %%
f, ax = plt.subplots()
sns.violinplot(data)
sns.despine(offset = 10, trim = True);

# %%
with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %%
import pandas as pd
pd.cut(np.array([.01, 1.4, 2.5, 6.2, 9.7, 2.1]), 3, retbins=True)
# Out:
# ([(0.00031, 3.24], (0.00031, 3.24], (0.00031, 3.24], (3.24, 6.47], (6.47, 9.7], (0.00031, 3.24]]
#  Categories (3, object): [(0.00031, 3.24] < (3.24, 6.47] < (6.47, 9.7]],
#  array([  3.10000000e-04,   3.24000000e+00,   6.47000000e+00,
#           9.70000000e+00]))

# %%
sns.set()

# %%
sns.set_context('paper')
plt.figure(figsize=(7.1,4))
sinplot()

# %%
sns.set_context('talk')
plt.figure(figsize = (7.1,4))
sinplot()
