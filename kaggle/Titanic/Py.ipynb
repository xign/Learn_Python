# %%
import csv as csv
import numpy as np
import pylab as p
# %pylab inline

csv_file_object = csv.reader(open('train.csv', 'rb'))
header = csv_file_object.next()

data = []
for row in csv_file_object:
	data.append(row)
data = np.array(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data
# Out:
# array([['1', '0', '3', ..., '7.25', '', 'S'],
#        ['2', '1', '1', ..., '71.2833', 'C85', 'C'],
#        ['3', '1', '3', ..., '7.925', '', 'S'],
#        ...,
#        ['889', '0', '3', ..., '23.45', '', 'S'],
#        ['890', '1', '1', ..., '30', 'C148', 'C'],
#        ['891', '0', '3', ..., '7.75', '', 'Q']],
#       dtype='|S82')

# %%
type(data[0::, 5])
# Out:
# numpy.ndarray

# %%
import pandas as pd
df = pd.read_csv('train.csv', header = 0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'][0:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
df.Age[0:10]
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# 6    54
# 7     2
# 8    27
# 9    14
# Name: Age, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df[['Sex', 'Pclass', 'Age']]
# Out:
#         Sex  Pclass  Age
# 0      male       3   22
# 1    female       1   38
# 2    female       3   26
# 3    female       1   35
# 4      male       3   35
# 5      male       3  NaN
# 6      male       1   54
# 7      male       3    2
# 8    female       3   27
# 9    female       2   14
# 10   female       3    4
# 11   female       1   58
# 12     male       3   20
# 13     male       3   39
# 14   female       3   14
# 15   female       2   55
# 16     male       3    2
# 17     male       2  NaN
# 18   female       3   31
# 19   female       3  NaN
# 20     male       2   35
# 21     male       2   34
# 22   female       3   15
# 23     male       1   28
# 24   female       3    8
# 25   female       3   38
# 26     male       3  NaN
# 27     male       1   19
# 28   female       3  NaN
# 29     male       3  NaN
# ..      ...     ...  ...
# 861    male       2   21
# 862  female       1   48
# 863  female       3  NaN
# 864    male       2   24
# 865  female       2   42
# ...

# %%
type(df[['Sex', 'Pclass', 'Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[df['Age'] > 60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
df[df['Age'] > 60][['Sex', 'Pclass', 'Age', 'Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0

# %%
df[['Sex', 'Pclass', 'Age', 'Survived']][df['Age'] > 60]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0

# %%
df[df['Age'].isnull()][['Sex','Pclass', 'Survived']]
# Out:
#         Sex  Pclass  Survived
# 5      male       3         0
# 17     male       2         1
# 19   female       3         1
# 26     male       3         0
# 28   female       3         1
# 29     male       3         0
# 31   female       1         1
# 32   female       3         1
# 36     male       3         1
# 42     male       3         0
# 45     male       3         0
# 46     male       3         0
# 47   female       3         1
# 48     male       3         0
# 55     male       1         1
# 64     male       1         0
# 65     male       3         1
# 76     male       3         0
# 77     male       3         0
# 82   female       3         1
# 87     male       3         0
# 95     male       3         0
# 101    male       3         0
# 107    male       3         1
# 109  female       3         1
# 121    male       3         0
# 126    male       3         0
# 128  female       3         1
# 140  female       3         0
# 154    male       3         0
# ...

# %%
for i in range(1,4):
    print i, len(df[(df['Sex'] == 'male') & (df['Pclass'] == i)])
# Out:
# 1 122
# 2 108
# 3 347

# %%
df['Gender'] = 4

# %%
df['Gender'] = [x[0].upper() for x in df['Sex']]

# %%
df['G'] = df['Sex'].map(lambda x : x[0].upper() )

# %%
sum(df['Gender'] != df['G'])
# Out:
# 0

# %%
df['Gender'] = df['Sex'].map({'female': 0, 'male':1}).astype(int)

# %%
df['G'] = (df['Sex'] == 'male').astype(int)

# %%
sum(df['G'] != df['Gender'])
# Out:
# 0

# %%
median_ages = np.zeros((2,3))

# %%
for i in range(0,2):
    for j in range(0,3):
        median_ages[i,j] = df[(df['Gender'] == i) & \
                             (df['Pclass'] == j+1)]['Age'].dropna().median()
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df['Age']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  G  AgeFill
# 0      0         A/5 21171   7.2500   NaN        S       1  1       22
# 1      0          PC 17599  71.2833   C85        C       0  0       38
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0  0       26
# ...

# %%
df[df['Age'].isnull()][['Gender','Pclass','Age','AgeFill']].head()
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN      NaN
# 17       1       2  NaN      NaN
# 19       0       3  NaN      NaN
# 26       1       3  NaN      NaN
# 28       0       3  NaN      NaN

# %%
for i in range(0,2):
    for j in range(0,3):
        df.loc[(df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1), 'AgeFill'] = median_ages[i,j]

# %%
df.loc[1:5,'Age']
# Out:
# 1    38
# 2    26
# 3    35
# 4    35
# 5   NaN
# Name: Age, dtype: float64

# %%
df['Age'][1:5]
# Out:
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %%
df[1:5]['Age']
# Out:
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %%
df[df['Age'].isnull()][['Gender','Pclass','Age','AgeFill']].head()
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5

# %%
df['AgeIsNull'] = 28
# Out:
# 0      28
# 1      28
# 2      28
# 3      28
# 4      28
# 5      28
# 6      28
# 7      28
# 8      28
# 9      28
# 10     28
# 11     28
# 12     28
# 13     28
# 14     28
# 15     28
# 16     28
# 17     28
# 18     28
# 19     28
# 20     28
# 21     28
# 22     28
# 23     28
# 24     28
# 25     28
# 26     28
# 27     28
# 28     28
# 29     28
#        ..
# 861    28
# 862    28
# 863    28
# 864    28
# 865    28
# 866    28
# 867    28
# 868    28
# 869    28
# 870    28
# 871    28
# 872    28
# 873    28
# 874    28
# 875    28
# 876    28
# 877    28
# 878    28
# 879    28
# 880    28
# 881    28
# 882    28
# 883    28
# 884    28
# 885    28
# 886    28
# 887    28
# 888    28
# 889    28
# 890    28
# Name: AgeIsNull, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
df['Age*Class'] = df.AgeFill * df.Pclass

# %%
df['Age*Class'].hist()
p.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 18 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Gender         891 non-null int64
# G              891 non-null int64
# AgeFill        891 non-null float64
# AgeIsNull      891 non-null int64
# FamilySize     891 non-null int64
# Age*Class      891 non-null float64
# dtypes: float64(4), int64(9), object(5)
# memory usage: 132.3+ KB

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin'], axis = 1)

# %%
df[0:5]
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare Embarked  Gender  \
# 0            1         0       3   22      1      0   7.2500        S       1
# 1            2         1       1   38      1      0  71.2833        C       0
# 2            3         1       3   26      0      0   7.9250        S       0
# 3            4         1       1   35      1      0  53.1000        S       0
# 4            5         0       3   35      0      0   8.0500        S       1
#
#    G  AgeFill  AgeIsNull  FamilySize  Age*Class
# 0  1       22         28           1         66
# 1  0       38         28           1         38
# 2  0       26         28           0         78
# 3  0       35         28           1         35
# 4  1       35         28           0        105

# %%
df[df['Age'].isnull()] = df['Age'].median()

# %%
df['Age'].median()
# Out:
# 28.0

# %%
df2 = df1.drop(['Embarked'], axis = 1)
df2
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch      Fare  Gender  G  \
# 0              1         0       3      1      0    7.2500       1  1
# 1              2         1       1      1      0   71.2833       0  0
# 2              3         1       3      0      0    7.9250       0  0
# 3              4         1       1      1      0   53.1000       0  0
# 4              5         0       3      0      0    8.0500       1  1
# 5              6         0       3      0      0    8.4583       1  1
# 6              7         0       1      0      0   51.8625       1  1
# 7              8         0       3      3      1   21.0750       1  1
# 8              9         1       3      0      2   11.1333       0  0
# 9             10         1       2      1      0   30.0708       0  0
# 10            11         1       3      1      1   16.7000       0  0
# 11            12         1       1      0      0   26.5500       0  0
# ...

# %%
df4 = df2
df4['Embarked'] = df1['Embarked'].map({'C':0, 'S':1, 'Q':2})
df4
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch      Fare  Gender  G  \
# 0              1         0       3      1      0    7.2500       1  1
# 1              2         1       1      1      0   71.2833       0  0
# 2              3         1       3      0      0    7.9250       0  0
# 3              4         1       1      1      0   53.1000       0  0
# 4              5         0       3      0      0    8.0500       1  1
# 5              6         0       3      0      0    8.4583       1  1
# 6              7         0       1      0      0   51.8625       1  1
# 7              8         0       3      3      1   21.0750       1  1
# 8              9         1       3      0      2   11.1333       0  0
# 9             10         1       2      1      0   30.0708       0  0
# 10            11         1       3      1      1   16.7000       0  0
# 11            12         1       1      0      0   26.5500       0  0
# ...

# %%
df5 = df4.ix[:,['Survived', 'Pclass', 'Fare', 'Gender', 'FamilySize']]
train_data = df5.values
train_data
# Out:
# array([[  0.    ,   3.    ,   7.25  ,   1.    ,   1.    ],
#        [  1.    ,   1.    ,  71.2833,   0.    ,   1.    ],
#        [  1.    ,   3.    ,   7.925 ,   0.    ,   0.    ],
#        ...,
#        [  0.    ,   3.    ,  23.45  ,   0.    ,   3.    ],
#        [  1.    ,   1.    ,  30.    ,   1.    ,   0.    ],
#        [  0.    ,   3.    ,   7.75  ,   1.    ,   0.    ]])

# %%
data
# Out:
# [['PassengerId',
#   'Pclass',
#   'Name',
#   'Sex',
#   'Age',
#   'SibSp',
#   'Parch',
#   'Ticket',
#   'Fare',
#   'Cabin',
#   'Embarked'],
#  ['892',
#   '3',
#   'Kelly, Mr. James',
#   'male',
#   '34.5',
#   '0',
#   '0',
#   '330911',
#   '7.8292',
#   '',
#   'Q'],
#  ['893',
#   '3',
#   'Wilkes, Mrs. James (Ellen Needs)',
#   'female',
#   '47',
#   '1',
#   '0',
#   '363272',
#   '7',
#   '',
#   'S'],
#  ['894',
#   '2',
#   'Myles, Mr. Thomas Francis',
#   'male',
#   '62',
#   '0',
#   '0',
#   '240276',
#   '9.6875',
#   '',
#   'Q'],
#  ['895',
#   '3',
#   'Wirz, Mr. Albert',
#   'male',
#   '27',
#   '0',
#   '0',
#   '315154',
#   '8.6625',
#   '',
#   'S'],
#  ['896',
#   '3',
#   'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#   'female',
#   '22',
#   '1',
#   '1',
#   '3101298',
#   '12.2875',
#   '',
#   'S'],
#  ['897',
#   '3',
#   'Svensson, Mr. Johan Cervin',
#   'male',
#   '14',
#   '0',
#   '0',
#   '7538',
#   '9.225',
#   '',
#   'S'],
# ...

# %%
from sklearn import linear_model

# %%
cf = linear_model.LogisticRegression()

# %%
cf.fit(train_data[:,1:], train_data[:,0])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)

# %%
sum(cf.predict(train_data[:,1:]) != train_data[:,0])
# Out:
# 178

# %%
csv2 = csv.reader(open('test.csv', 'rb'))

# %%
data = []
for row in csv2:
	data.append(row)
data0 = np.array(data)

# %%
data0
# Out:
# array([['PassengerId', 'Pclass', 'Name', ..., 'Fare', 'Cabin', 'Embarked'],
#        ['892', '3', 'Kelly, Mr. James', ..., '7.8292', '', 'Q'],
#        ['893', '3', 'Wilkes, Mrs. James (Ellen Needs)', ..., '7', '', 'S'],
#        ...,
#        ['1307', '3', 'Saether, Mr. Simon Sivertsen', ..., '7.25', '', 'S'],
#        ['1308', '3', 'Ware, Mr. Frederick', ..., '8.05', '', 'S'],
#        ['1309', '3', 'Peter, Master. Michael J', ..., '22.3583', '', 'C']],
#       dtype='|S63')

# %%
df0 = pd.read_csv('test.csv', header = 0)
df0 = df0.ix[:,['Pclass', 'Fare', 'Sex', 'SibSp','Parch']]
df0
# Out:
#      Pclass      Fare     Sex  SibSp  Parch
# 0         3    7.8292    male      0      0
# 1         3    7.0000  female      1      0
# 2         2    9.6875    male      0      0
# 3         3    8.6625    male      0      0
# 4         3   12.2875  female      1      1
# 5         3    9.2250    male      0      0
# 6         3    7.6292  female      0      0
# 7         2   29.0000    male      1      1
# 8         3    7.2292  female      0      0
# 9         3   24.1500    male      2      0
# 10        3    7.8958    male      0      0
# 11        1   26.0000    male      0      0
# 12        1   82.2667  female      1      0
# 13        2   26.0000    male      1      0
# 14        1   61.1750  female      1      0
# 15        2   27.7208  female      1      0
# 16        2   12.3500    male      0      0
# 17        3    7.2250    male      0      0
# 18        3    7.9250  female      1      0
# 19        3    7.2250  female      0      0
# ...

# %%
df5
# Out:
#      Survived  Pclass      Fare  Gender  FamilySize
# 0           0       3    7.2500       1           1
# 1           1       1   71.2833       0           1
# 2           1       3    7.9250       0           0
# 3           1       1   53.1000       0           1
# 4           0       3    8.0500       1           0
# 5           0       3    8.4583       1           0
# 6           0       1   51.8625       1           0
# 7           0       3   21.0750       1           4
# 8           1       3   11.1333       0           2
# 9           1       2   30.0708       0           1
# 10          1       3   16.7000       0           2
# 11          1       1   26.5500       0           0
# 12          0       3    8.0500       1           0
# 13          0       3   31.2750       1           6
# 14          0       3    7.8542       0           0
# 15          1       2   16.0000       0           0
# 16          0       3   29.1250       1           5
# ...

# %%
df0['Gender'] = (df0['Sex'] == 'male').astype(int)
df0['FamilySize'] = df0['SibSp'] + df0['Parch']

# %%
df00 = df0.ix[:, ['Pclass', 'Fare', 'Gender', 'FamilySize']]
df00
# Out:
#      Pclass      Fare  Gender  FamilySize
# 0         3    7.8292       1           0
# 1         3    7.0000       0           1
# 2         2    9.6875       1           0
# 3         3    8.6625       1           0
# 4         3   12.2875       0           2
# 5         3    9.2250       1           0
# 6         3    7.6292       0           0
# 7         2   29.0000       1           2
# 8         3    7.2292       0           0
# 9         3   24.1500       1           2
# 10        3    7.8958       1           0
# 11        1   26.0000       1           0
# 12        1   82.2667       0           1
# 13        2   26.0000       1           1
# 14        1   61.1750       0           1
# 15        2   27.7208       0           1
# 16        2   12.3500       1           0
# 17        3    7.2250       1           0
# 18        3    7.9250       0           1
# 19        3    7.2250       0           0
# 20        1   59.4000       1           1
# ...

# %%
df00.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 4 columns):
# Pclass        418 non-null int64
# Fare          417 non-null float64
# Gender        418 non-null int64
# FamilySize    418 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 16.3 KB
