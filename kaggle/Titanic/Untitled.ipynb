# %%
import csv as csv
import numpy as np
import pylab as p
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['clf']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import pandas as pd
df = pd.read_csv('train.csv', header = 0)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df0 = df.drop(["Cabin","Ticket","Name"],axis = 1)

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 69.6+ KB

# %%
df0['Nembarked']=df0["Embarked"].map({'S':1,'Q':2,'C':3})

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# Nembarked      889 non-null float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 76.6+ KB

# %%
df1 = df0
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare   Nembarked
# count  891.000000  891.000000  889.000000
# mean     0.381594   32.204208    1.464567
# std      0.806057   49.693429    0.792088
# min      0.000000    0.000000    1.000000
# 25%      0.000000    7.910400    1.000000
# 50%      0.000000   14.454200    1.000000
# 75%      0.000000   31.000000    2.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# Embarked       889 non-null object
# Nembarked      889 non-null float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 76.6+ KB

# %%
df2 = df1.dropna().drop("Embarked",axis = 1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    712 non-null int64
# Survived       712 non-null int64
# Pclass         712 non-null int64
# Sex            712 non-null object
# Age            712 non-null float64
# SibSp          712 non-null int64
# Parch          712 non-null int64
# Fare           712 non-null float64
# Nembarked      712 non-null float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 55.6+ KB

# %%
df2['Sex'] = (df2['Sex']=='male').astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 9 columns):
# PassengerId    712 non-null int64
# Survived       712 non-null int64
# Pclass         712 non-null int64
# Sex            712 non-null int64
# Age            712 non-null float64
# SibSp          712 non-null int64
# Parch          712 non-null int64
# Fare           712 non-null float64
# Nembarked      712 non-null float64
# dtypes: float64(3), int64(6)
# memory usage: 55.6 KB

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch      Fare  \
# 0              1         0       3    1   22      1      0    7.2500
# 1              2         1       1    0   38      1      0   71.2833
# 2              3         1       3    0   26      0      0    7.9250
# 3              4         1       1    0   35      1      0   53.1000
# 4              5         0       3    1   35      0      0    8.0500
# 6              7         0       1    1   54      0      0   51.8625
# 7              8         0       3    1    2      3      1   21.0750
# 8              9         1       3    0   27      0      2   11.1333
# 9             10         1       2    0   14      1      0   30.0708
# 10            11         1       3    0    4      1      1   16.7000
# 11            12         1       1    0   58      0      0   26.5500
# 12            13         0       3    1   20      0      0    8.0500
# 13            14         0       3    1   39      1      5   31.2750
# ...

# %%
data = df2.drop('PassengerId', axis = 1)

# %%
data_value = data.values

# %%
print data_value
# Out:
# [[  0.       3.       1.     ...,   0.       7.25     1.    ]
#  [  1.       1.       0.     ...,   0.      71.2833   3.    ]
#  [  1.       3.       0.     ...,   0.       7.925    1.    ]
#  ...,
#  [  1.       1.       0.     ...,   0.      30.       1.    ]
#  [  1.       1.       1.     ...,   0.      30.       3.    ]
#  [  0.       3.       1.     ...,   0.       7.75     2.    ]]

# %%
# Out:
#   File "<ipython-input-220-70fbef4bd6b9>", line 1
#     data_value.[0]
#                ^
# SyntaxError: invalid syntax

# %%
data.cov()
# Out:
#            Survived     Pclass       Sex         Age     SibSp     Parch  \
# Survived   0.241217  -0.146510 -0.126914   -0.586853 -0.007096  0.039966
# Pclass    -0.146510   0.700325  0.060765   -4.437831  0.050771  0.016917
# Sex       -0.126914   0.060765  0.231765    0.691001 -0.047626 -0.102617
# Age       -0.586853  -4.437831  0.691001  210.045104 -4.145690 -2.326082
# SibSp     -0.007096   0.050771 -0.047626   -4.145690  0.866188  0.304746
# Parch      0.039966   0.016917 -0.102617   -2.326082  0.304746  0.729626
# Fare       6.918651 -24.494240 -4.650045   71.462319  6.890868  9.343359
# Nembarked  0.069628  -0.159168 -0.041119    0.367676 -0.023973 -0.007854
#
#                   Fare  Nembarked
# Survived      6.918651   0.069628
# Pclass      -24.494240  -0.159168
# Sex          -4.650045  -0.041119
# Age          71.462319   0.367676
# SibSp         6.890868  -0.023973
# Parch         9.343359  -0.007854
# Fare       2802.500471  11.692310
# ...

# %%
data.corr()
# Out:
#            Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived   1.000000 -0.356462 -0.536762 -0.082446 -0.015523  0.095265
# Pclass    -0.356462  1.000000  0.150826 -0.365902  0.065187  0.023666
# Sex       -0.536762  0.150826  1.000000  0.099037 -0.106296 -0.249543
# Age       -0.082446 -0.365902  0.099037  1.000000 -0.307351 -0.187896
# SibSp     -0.015523  0.065187 -0.106296 -0.307351  1.000000  0.383338
# Parch      0.095265  0.023666 -0.249543 -0.187896  0.383338  1.000000
# Fare       0.266100 -0.552893 -0.182457  0.093143  0.139860  0.206624
# Nembarked  0.181979 -0.244145 -0.109639  0.032565 -0.033064 -0.011803
#
#                Fare  Nembarked
# Survived   0.266100   0.181979
# Pclass    -0.552893  -0.244145
# Sex       -0.182457  -0.109639
# Age        0.093143   0.032565
# SibSp      0.139860  -0.033064
# Parch      0.206624  -0.011803
# Fare       1.000000   0.283510
# Nembarked  0.283510   1.000000

# %%
from scipy.stats import pearsonr
pearsonr(data['Age'], data['Sex'])
#第一个为相关度,第二个为p-value
# Out:
# (0.099037226916778964, 0.0081810841092485511)

# %%
from sklearn.ensemble import RandomForestRegressor
ctf = RandomForestRegressor()
x = data_value[:600,1:]
y = data_value[:600,0]
ctf.fit(x, y)
q = pd.DataFrame(ctf.feature_importances_ ,columns = ["Info"])
q["Factor"]= ['Pclass', 'Age','Sex','SibSp','Parch','Fare','Nembarked']

# %%
q
# Out:
#        Info     Factor
# 0  0.140815     Pclass
# 1  0.295471        Age
# 2  0.255023        Sex
# 3  0.056987      SibSp
# 4  0.020991      Parch
# 5  0.208431       Fare
# 6  0.022282  Nembarked

# %%
nx = ctf.fit(x, y).transform(x)
nx.shape
# Out:
# (600, 3)

# %%
nx
# Out:
# array([[  1.    ,  22.    ,   7.25  ],
#        [  0.    ,  38.    ,  71.2833],
#        [  0.    ,  26.    ,   7.925 ],
#        ...,
#        [  1.    ,   6.    ,  12.475 ],
#        [  1.    ,  33.    ,   9.5   ],
#        [  1.    ,  23.    ,   7.8958]])

# %%
d_value = df2[['Survived','Pclass','Age','Sex','Fare']].values

# %%
d_value
# Out:
# array([[  0.    ,   3.    ,  22.    ,   1.    ,   7.25  ],
#        [  1.    ,   1.    ,  38.    ,   0.    ,  71.2833],
#        [  1.    ,   3.    ,  26.    ,   0.    ,   7.925 ],
#        ...,
#        [  1.    ,   1.    ,  19.    ,   0.    ,  30.    ],
#        [  1.    ,   1.    ,  26.    ,   1.    ,  30.    ],
#        [  0.    ,   3.    ,  32.    ,   1.    ,   7.75  ]])

# %%
dt_value = data_value[:,[0,1,2,3,6]]

# %%
dt_value
# Out:
# array([[  0.    ,   3.    ,   1.    ,  22.    ,   7.25  ],
#        [  1.    ,   1.    ,   0.    ,  38.    ,  71.2833],
#        [  1.    ,   3.    ,   0.    ,  26.    ,   7.925 ],
#        ...,
#        [  1.    ,   1.    ,   0.    ,  19.    ,  30.    ],
#        [  1.    ,   1.    ,   1.    ,  26.    ,  30.    ],
#        [  0.    ,   3.    ,   1.    ,  32.    ,   7.75  ]])

# %%
from sklearn import linear_model

# %%
cf = linear_model.LogisticRegression()

# %%
cf.fit(dt_value[:700,1:], dt_value[:700,0])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)

# %%
cf.score(dt_value[:700,1:], dt_value[:700,0])
# Out:
# 0.79428571428571426

# %%
sum(cf.predict(dt_value[700:,1:]) != dt_value[700:,0])
# Out:
# 2

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(dt_value[:700,1:], dt_value[:700,0])
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
clf.score(dt_value[:700,1:], dt_value[:700,0])
# Out:
# 0.92285714285714282

# %%
sum(clf.predict(dt_value[700:,1:]) != dt_value[700:,0])
# Out:
# 2

# %%
tdf = pd.read_csv('test.csv', header = 0)

# %%
tdf[:10]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 39.2+ KB

# %%
tdf = tdf[['Pclass','Sex','Age','Fare']]

# %%
tdf['Age'][tdf['Age'].isnull()] = tdf['Age'].mean()

# %%
tdf1 = tdf

# %%
tdf1['Sex'] = (tdf1['Sex']=='male').astype(int)

# %%
tdf2 = tdf1
tdf2
# Out:
#      Pclass  Sex       Age      Fare
# 0         3    1  34.50000    7.8292
# 1         3    0  47.00000    7.0000
# 2         2    1  62.00000    9.6875
# 3         3    1  27.00000    8.6625
# 4         3    0  22.00000   12.2875
# 5         3    1  14.00000    9.2250
# 6         3    0  30.00000    7.6292
# 7         2    1  26.00000   29.0000
# 8         3    0  18.00000    7.2292
# 9         3    1  21.00000   24.1500
# 10        3    1  30.27259    7.8958
# 11        1    1  46.00000   26.0000
# 12        1    0  23.00000   82.2667
# 13        2    1  63.00000   26.0000
# 14        1    0  47.00000   61.1750
# 15        2    0  24.00000   27.7208
# 16        2    1  35.00000   12.3500
# 17        3    1  21.00000    7.2250
# 18        3    0  27.00000    7.9250
# 19        3    0  45.00000    7.2250
# 20        1    1  55.00000   59.4000
# 21        3    1   9.00000    3.1708
# 22        1    0  30.27259   31.6833
# 23        1    1  21.00000   61.3792
# ...

# %%
tdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 4 columns):
# Pclass    418 non-null int64
# Sex       418 non-null int64
# Age       418 non-null float64
# Fare      417 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 16.3 KB

# %%
tdf2[tdf2['Fare'].isnull()]
# Out:
#      Pclass  Sex   Age  Fare
# 152       3    1  60.5   NaN

# %%
tdf2[tdf2['Pclass'] == 3].describe()
# Out:
#        Pclass         Sex         Age        Fare
# count     218  218.000000  218.000000  217.000000
# mean        3    0.669725   26.090397   12.459678
# std         0    0.471395    9.102542   10.803698
# min         3    0.000000    0.170000    3.170800
# 25%         3    0.000000   21.250000    7.750000
# 50%         3    1.000000   29.500000    7.895800
# 75%         3    1.000000   30.272590   14.400000
# max         3    1.000000   60.500000   69.550000

# %%
tdf2[tdf2['Fare'].isnull()]
tdf2.ix[152,3] = 12.459678

# %%
tdf2.describe()
# Out:
#            Pclass         Sex         Age        Fare
# count  418.000000  418.000000  418.000000  418.000000
# mean     2.265550    0.636364   30.272590   35.571764
# std      0.841838    0.481622   12.634534   55.851997
# min      1.000000    0.000000    0.170000    0.000000
# 25%      1.000000    0.000000   23.000000    7.895800
# 50%      3.000000    1.000000   30.272590   14.454200
# 75%      3.000000    1.000000   35.750000   31.471875
# max      3.000000    1.000000   76.000000  512.329200

# %%
tdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 0 to 417
# Data columns (total 4 columns):
# Pclass    418 non-null int64
# Sex       418 non-null int64
# Age       418 non-null float64
# Fare      418 non-null float64
# dtypes: float64(2), int64(2)
# memory usage: 16.3 KB

# %%
tdf2_value = tdf2.values
tdf2_value
# Out:
# array([[  3.        ,   1.        ,  34.5       ,   7.8292    ],
#        [  3.        ,   0.        ,  47.        ,   7.        ],
#        [  2.        ,   1.        ,  62.        ,   9.6875    ],
#        ...,
#        [  3.        ,   1.        ,  38.5       ,   7.25      ],
#        [  3.        ,   1.        ,  30.27259036,   8.05      ],
#        [  3.        ,   1.        ,  30.27259036,  22.3583    ]])

# %%
dt_value[:10]
# Out:
# array([[  0.    ,   3.    ,   1.    ,  22.    ,   7.25  ],
#        [  1.    ,   1.    ,   0.    ,  38.    ,  71.2833],
#        [  1.    ,   3.    ,   0.    ,  26.    ,   7.925 ],
#        [  1.    ,   1.    ,   0.    ,  35.    ,  53.1   ],
#        [  0.    ,   3.    ,   1.    ,  35.    ,   8.05  ],
#        [  0.    ,   1.    ,   1.    ,  54.    ,  51.8625],
#        [  0.    ,   3.    ,   1.    ,   2.    ,  21.075 ],
#        [  1.    ,   3.    ,   0.    ,  27.    ,  11.1333],
#        [  1.    ,   2.    ,   0.    ,  14.    ,  30.0708],
#        [  1.    ,   3.    ,   0.    ,   4.    ,  16.7   ]])

# %%
db = tdf2_value

# %%
testvalue = clf.predict(db)

# %%
x = pd.read_csv('test.csv', header = 0)

# %%
t = pd.DataFrame(x['PassengerId'])

# %%
t['Survived'] = pd.DataFrame(testvalue)

# %%
t['Survived'].astype(int)
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
# 5      0
# 6      0
# 7      1
# 8      1
# 9      1
# 10     0
# 11     0
# 12     1
# 13     0
# 14     0
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     1
# 21     0
# 22     1
# 23     1
# 24     0
# 25     0
# 26     1
# 27     0
# 28     1
# 29     0
#       ..
# 388    0
# 389    1
# 390    1
# 391    1
# 392    1
# 393    0
# 394    0
# 395    1
# 396    0
# 397    0
# 398    0
# 399    0
# 400    1
# 401    1
# 402    0
# 403    0
# 404    0
# 405    0
# 406    0
# 407    0
# 408    0
# 409    1
# 410    0
# 411    1
# 412    0
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, dtype: int64

# %%
t
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         1
# 3            895         0
# 4            896         0
# 5            897         0
# 6            898         0
# 7            899         1
# 8            900         1
# 9            901         1
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         0
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         0
# 20           912         1
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         0
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         1
# ...

# %%
oy = t.to_csv('After3.csv', index = False)
